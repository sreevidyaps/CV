# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
image_path = '/content/Black Golden Modern Luxury Logo copy.png'
frame = cv2.imread(image_path)

# %%
if frame is None:
    print("Error loading image")
else:
    pts1 = np.float32([[0, 260], [640, 260], [0, 400], [640, 400]])
    pts2 = np.float32([[0, 0], [400, 0], [0, 640], [400, 640]])

# %%
matrix = cv2.getPerspectiveTransform(pts1, pts2)
result = cv2.warpPerspective(frame, matrix, (500, 1000))

# %%
cv2_imshow(frame)
cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=RGB size=1563x1563>
# <PIL.Image.Image image mode=RGB size=500x1000>
